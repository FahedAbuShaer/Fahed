# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Euler's Method**

# %%
# the coupled first ordinary differential equations for a harmonic oscillator are
# x' = v
# v' = -w^2 x
hs = []
errors = []
for j in range(0, 101, 10): #fix this to let h go from 0.001 to 0.1 with 0.05 step scale
    if j == 0:
        h = 0.1
        n = 50
    else:
        h = 0.1/j
        n = 50 * j
    t = np.zeros(n+1)
    x = np.zeros(n+1)
    v = np.zeros(n+1)
    w2 = 10
    x[0] = 5
    v[0] = 0
    for i in range(n):
        x[i+1] = x[i] + h * v[i]
        v[i+1] = v[i] - h * w2 * x[i]
        t[i+1] = t[i] + h
    x2 = 5 * np.cos(np.sqrt(w2)*t)
    error= np.sum((x2-x) ** 2)/n
    errors.append(error)
    hs.append(h)
#     plt.plot(t, x, label = "Numerical Value")
#     plt.plot(t, x2, color = 'r', label = "Analytical Value")
#     plt.legend(loc = 'lower left')
#     plt.xlabel("time")
#     plt.ylabel("position")
#     print("h = ", h, " n =  ", n, " error = ", error)
#     plt.show()
# print("hs = ", hs, "\nerrors = ", errors)
# plt.plot(hs, errors)
# plt.scatter(hs, errors)
# plt.xlabel("distance between the points")
# plt.ylabel("error")
# plt.show()

# %% [markdown]
# ## **The Runge-Kutta Method of Order 2**

# %%
hs = []
errors = []
for j in range(0, 101, 10):
    if j == 0:
        h = 0.1
        n = 50
    else:
        h = 0.1/j
        n = 50 * j
    t = np.zeros(n+1)
    x = np.zeros(n+1)
    v = np.zeros(n+1)
    w2 = 10
    x[0] = 5
    v[0] = 0
    for i in range(1, n + 1):
        k = h * (-w2 * x[i-1])
        x[i] = x[i - 1] + h * v[i - 1]
        v[i] = v[i - 1] - h * w2 * (x[i - 1] + (k/2))
        t[i] = t[i - 1] + h
#     plt.plot(t, x)
#     x2 = 5 * np.cos(np.sqrt(w2)*t)
#     error= np.sum((x2-x) ** 2)/n
#     errors.append(error)
#     hs.append(h)
#     plt.plot(t, x2, color = 'r')
#     print("h = ", h, " n =  ", n, " error = ", error)
#     plt.show()
# print("hs = ", hs, "\nerrors = ", errors)
# plt.plot(hs, errors)
# plt.scatter(hs, errors)
# plt.xlabel("distance between the points")
# plt.ylabel("error")
# plt.show()

# %%
hs = []
errors = []
for j in range(0, 101, 10):
    if j == 0:
        h = 0.1
        n = 50
    else:
        h = 0.1/j
        n = 50 * j
    x_0, v_0, w2 = 5, 0, 10
    t, x = RK2(h, n, x_0, v_0, w2) 
#     plt.plot(t, x, label = "Numerical Value")
#     x2 = 5 * np.cos(np.sqrt(w2)*t)
#     error= np.sum((x2-x) ** 2)/n
#     errors.append(error)
#     hs.append(h)
#     plt.plot(t, x2, color = 'r', label = "Analytic Value")
#     print("h = ", h, " n =  ", n, " error = ", error)
#     plt.legend(loc = 'lower left')
#     plt.xlabel("time")
#     plt.ylabel("position")
#     plt.show()
# print("hs = ", hs, "\nerrors = ", errors)
# plt.plot(hs, errors)
# plt.scatter(hs, errors)
# plt.xlabel("distance between the points")
# plt.ylabel("error")
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\USAID\Desktop\PHYS 222\Github Folder\Fahed\Homework\Chapter 3\ODE.ipynb Cell 6 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/USAID/Desktop/PHYS%20222/Github%20Folder/Fahed/Homework/Chapter%203/ODE.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a>         n = 50 * j
#      <a href='vscode-notebook-cell:/c%3A/Users/USAID/Desktop/PHYS%20222/Github%20Folder/Fahed/Homework/Chapter%203/ODE.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a>     x_0, v_0, w2 = 5, 0, 10
# ---> <a href='vscode-notebook-cell:/c%3A/Users/USAID/Desktop/PHYS%20222/Github%20Folder/Fahed/Homework/Chapter%203/ODE.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a>     t, x = RK2(h, n, x_0, v_0, w2)
#      <a href='vscode-notebook-cell:/c%3A/Users/USAID/Desktop/PHYS%20222/Github%20Folder/Fahed/Homework/Chapter%203/ODE.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a> #     plt.plot(t, x, label = "Numerical Value")
#      <a href='vscode-notebook-cell:/c%3A/Users/USAID/Desktop/PHYS%20222/Github%20Folder/Fahed/Homework/Chapter%203/ODE.ipynb#W5sZmlsZQ%3D%3D?line=12'>13</a> #     x2 = 5 * np.cos(np.sqrt(w2)*t)
#      <a href='vscode-notebook-cell:/c%3A/Users/USAID/Desktop/PHYS%20222/Github%20Folder/Fahed/Homework/Chapter%203/ODE.ipynb#W5sZmlsZQ%3D%3D?line=13'>14</a> #     error= np.sum((x2-x) ** 2)/n
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/USAID/Desktop/PHYS%20222/Github%20Folder/Fahed/Homework/Chapter%203/ODE.ipynb#W5sZmlsZQ%3D%3D?line=26'>27</a> # plt.ylabel("error")
#      <a href='vscode-notebook-cell:/c%3A/Users/USAID/Desktop/PHYS%20222/Github%20Folder/Fahed/Homework/Chapter%203/ODE.ipynb#W5sZmlsZQ%3D%3D?line=27'>28</a> # plt.show()
#
# NameError: name 'RK2' is not defined

# %% [markdown]
# ## **The Runge-Kutta Method of Order 4**

# %%
# this is giving me the same result as order 2
hs = []
errors = []
for j in range(0, 101, 10):
    if j == 0:
        h = 0.1
        n = 50
    else:
        h = 0.1/j
        n = 50 * j
    t = np.zeros(n+1)
    x = np.zeros(n+1)
    v = np.zeros(n+1)
    w2 = 10
    x[0] = 5
    v[0] = 0
    for i in range(1, n + 1):
        k1 = h * (-w2 * x[i-1])
        k2 = h * (-w2 * (x[i-1] + (k1/2)))
        k3 = h * (-w2 * (x[i-1] + (k2/2)))
        k4 = h * (-w2 * (x[i-1] + k3))
        x[i] = x[i - 1] + h * v[i - 1]
        v[i] = v[i - 1] + (1/6) * (k1 + 2 * k2 + 2 * k3 + k4)
        t[i] = t[i - 1] + h
#     plt.plot(t, x, label = "Numerical Value")
#     x2 = 5 * np.cos(np.sqrt(w2)*t)
#     error= np.sum((x2-x) ** 2)/n
#     errors.append(error)
#     hs.append(h)
#     plt.plot(t, x2, color = 'r', label = "Analytic Value")
#     print("h = ", h, " n =  ", n, " error = ", error)
#     plt.legend(loc = 'lower left')
#     plt.xlabel("time")
#     plt.ylabel("position")
#     plt.show()
# print("hs = ", hs, "\nerrors = ", errors)
# plt.plot(hs, errors)
# plt.scatter(hs, errors)
# plt.xlabel("distance between the points")
# plt.ylabel("error")
# plt.show()

# %%
hs = []
errors = []
for j in range(0, 101, 10):
    if j == 0:
        h = 0.1
        n = 50
    else:
        h = 0.1/j
        n = 50 * j
    x_0, v_0, w2 = 5, 0, 10
    t, x = RK4(h, n, x_0, v_0, w2)
#     plt.plot(t, x, label = "Numerical Value")
#     x2 = 5 * np.cos(np.sqrt(w2)*t)
#     error= np.sum((x2-x) ** 2)/n
#     errors.append(error)
#     hs.append(h)
#     plt.plot(t, x2, color = 'r', label = "Analytic Value")
#     print("h = ", h, " n =  ", n, " error = ", error)
#     plt.legend(loc = 'lower left')
#     plt.xlabel("time")
#     plt.ylabel("position")
#     plt.show()
# print("hs = ", hs, "\nerrors = ", errors)
# plt.plot(hs, errors)
# plt.scatter(hs, errors)
# plt.xlabel("distance between the points")
# plt.ylabel("error")
# plt.show()

# %% [markdown]
# ## **Comparison Between RK2 and RK4**

# %%
def RK2(h, n, x_0, v_0, w2):
    t = np.zeros(n+1)
    x = np.zeros(n+1)
    v = np.zeros(n+1)
    x[0] = x_0
    v[0] = v_0
    for i in range(1, n+1):
        k = h * (-w2 * x[i-1])
        x[i] = x[i - 1] + h * v[i - 1]
        v[i] = v[i - 1] - h * w2 * (x[i - 1] + (k/2))
        t[i] = t[i - 1] + h
    return t, x

# %%
def RK4(h, n, x_0, v_0, w2):
    t = np.zeros(n+1)
    x = np.zeros(n+1)
    v = np.zeros(n+1)
    x[0] = x_0
    v[0] = v_0
    for i in range(1, n + 1):
        k1 = h * (-w2 * x[i-1])
        k2 = h * (-w2 * (x[i-1] + (k1/2)))
        k3 = h * (-w2 * (x[i-1] + (k2/2)))
        k4 = h * (-w2 * (x[i-1] + k3))
        x[i] = x[i - 1] + h * (v[i - 1])
        v[i] = v[i - 1] + (k1 + 2 * k2 + 2 * k3 + k4)/6
        t[i] = t[i - 1] + h
    return t, x

# %%
hs = []
errors1 = []
errors2 = []
for j in range(0, 101, 10):
    if j == 0:
        h = 0.1
        n = 50
    else:
        h = 0.1/j
        n = 50 * j
    x_0, v_0, w2 = 5, 0, 10
    t1, x1 = RK2(h, n, x_0, v_0, w2)
    t2, x2 = RK4(h, n, x_0, v_0, w2)
    x3 = x_0 * np.cos(np.sqrt(w2) * t1)
    plt.plot(t2, x3, label = 'Analytical')
    plt.plot(t1, x1, label = 'Numerical-RK2')
    plt.plot(t2, x2, label = 'Numerical-RK4')
    plt.legend(loc = "lower left")
    error1= np.sum((x3-x1) ** 2)/n
    errors1.append(error1)
    error2 = np.sum((x3-x2) ** 2)/n
    errors2.append(error2)
    hs.append(h)
    print("h = ", h, " n = ", n, " RK2 Error = ", error1, " RK4 Error = ", error2)
    # plt.xlim(4.5, 4.625)
    plt.show()
plt.plot(hs, errors1, label = "RK2 Errors")
plt.scatter(hs, errors1)
plt.scatter(hs, errors2)
plt.plot(hs, errors2, label = "RK4 Errors")
plt.xlabel("distance between the points")
plt.ylabel("error")
plt.show()
# Out:
# h =  0.1  n =  50  RK2 Error =  79.89924074450158  RK4 Error =  119.46996134333988
# h =  0.01  n =  500  RK2 Error =  1.0061552206859878  RK4 Error =  0.9573236495803107
# h =  0.005  n =  1000  RK2 Error =  0.2280175485437071  RK4 Error =  0.22249875429588262
# h =  0.0033333333333333335  n =  1500  RK2 Error =  0.09806172636026785  RK4 Error =  0.09648176141226239
# h =  0.0025  n =  2000  RK2 Error =  0.054258054832312726  RK4 Error =  0.05360293843192406
# h =  0.002  n =  2500  RK2 Error =  0.03438305219135263  RK4 Error =  0.03405110809422928
# h =  0.0016666666666666668  n =  3000  RK2 Error =  0.023719919662306424  RK4 Error =  0.02352915451885887
# h =  0.0014285714285714286  n =  3500  RK2 Error =  0.017344805420357646  RK4 Error =  0.01722526996141373
# h =  0.00125  n =  4000  RK2 Error =  0.013232663299795422  RK4 Error =  0.013152882619062261
# h =  0.0011111111111111111  n =  4500  RK2 Error =  0.010426664613626638  RK4 Error =  0.010370794871989868
# h =  0.001  n =  5000  RK2 Error =  0.008426994924650225  RK4 Error =  0.00838636062953767
